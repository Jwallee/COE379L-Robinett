# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

uri = "mongodb+srv://gogo1000200:6yvg5vWWruMIrzT1@cluster0.flcxgec.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
import os
os.environ['MONGODB_ATLAS_URI'] = 'mongodb+srv://gogo1000200:6yvg5vWWruMIrzT1@cluster0.flcxgec.mongodb.net/'

# %%
import os
from pymongo import MongoClient
import datasets
from datasets import load_dataset
from bson import json_util

# MongoDB Atlas URI and client setup
uri = os.environ.get('MONGODB_ATLAS_URI')
client = MongoClient(uri)

# Change to the appropriate database and collection names
db_name = 'airbnb'  # Change this to your actual database name
collection_name = 'listings'  # Change this to your actual collection name

collection = client[db_name][collection_name]

# Load the "airbnb_embeddings" dataset from Hugging Face
dataset = load_dataset("MongoDB/airbnb_embeddings")

insert_data = []

# Iterate through the dataset and prepare the documents for insertion
# The script below ingests 1000 records into the database at a time
for item in dataset['train']:
    # Convert the dataset item to MongoDB document format
    doc_item = json_util.loads(json_util.dumps(item))
    insert_data.append(doc_item)

    # Insert in batches of 1000 documents
    if len(insert_data) == 1000:
        collection.insert_many(insert_data)
        print("1000 records ingested")
        insert_data = []

# Insert any remaining documents
if len(insert_data) > 0:
    collection.insert_many(insert_data)
    print("{} records ingested".format(len(insert_data)))

print("All records ingested successfully!")
# Out:
# 1000 records ingested
# 1000 records ingested
# 1000 records ingested
# 1000 records ingested
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# Cell In[7], line 31
#      29 # Insert in batches of 1000 documents
#      30 if len(insert_data) == 1000:
# ---> 31     collection.insert_many(insert_data)
#      32     print("1000 records ingested")
#      33     insert_data = []
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pymongo/_csot.py:107, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     105         with _TimeoutContext(timeout):
#     106             return func(self, *args, **kwargs)
# --> 107 return func(self, *args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pymongo/collection.py:755, in Collection.insert_many(self, documents, ordered, bypass_document_validation, session, comment)
#     753 blk = _Bulk(self, ordered, bypass_document_validation, comment=comment)
#     754 blk.ops = list(gen())
# --> 755 blk.execute(write_concern, session=session)
#     756 return InsertManyResult(inserted_ids, write_concern.acknowledged)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pymongo/bulk.py:576, in _Bulk.execute(self, write_concern, session)
#     574         return None
#     575 else:
# --> 576     return self.execute_command(generator, write_concern, session)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pymongo/bulk.py:443, in _Bulk.execute_command(self, generator, write_concern, session)
#     432     self._execute_command(
#     433         generator,
#     434         write_concern,
#    (...)
#     439         full_result,
#     440     )
#     442 client = self.collection.database.client
# --> 443 client._retryable_write(self.is_retryable, retryable_bulk, session, bulk=self)
#     445 if full_result["writeErrors"] or full_result["writeConcernErrors"]:
#     446     _raise_bulk_write_error(full_result)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pymongo/mongo_client.py:1523, in MongoClient._retryable_write(self, retryable, func, session, bulk)
#    1509 """Execute an operation with consecutive retries if possible
#    1510
#    1511 Returns func()'s return value on success. On error retries the same
#    (...)
#    1520   - `bulk`: bulk abstraction to execute operations in bulk, defaults to None
#    1521 """
#    1522 with self._tmp_session(session) as s:
# -> 1523     return self._retry_with_session(retryable, func, s, bulk)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pymongo/mongo_client.py:1421, in MongoClient._retry_with_session(self, retryable, func, session, bulk)
#    1416 # Ensure that the options supports retry_writes and there is a valid session not in
#    1417 # transaction, otherwise, we will not support retry behavior for this txn.
#    1418 retryable = bool(
#    1419     retryable and self.options.retry_writes and session and not session.in_transaction
#    1420 )
# -> 1421 return self._retry_internal(
#    1422     func=func,
#    1423     session=session,
#    1424     bulk=bulk,
#    1425     retryable=retryable,
#    1426 )
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pymongo/_csot.py:107, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     105         with _TimeoutContext(timeout):
#     106             return func(self, *args, **kwargs)
# --> 107 return func(self, *args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pymongo/mongo_client.py:1462, in MongoClient._retry_internal(self, func, session, bulk, is_read, address, read_pref, retryable)
#    1428 @_csot.apply
#    1429 def _retry_internal(
#    1430     self,
#    (...)
#    1437     retryable: bool = False,
#    1438 ) -> T:
#    1439     """Internal retryable helper for all client transactions.
#    1440
#    1441     :Parameters:
#    (...)
#    1451       Output of the calling func()
#    1452     """
#    1453     return _ClientConnectionRetryable(
#    1454         mongo_client=self,
#    1455         func=func,
#    1456         bulk=bulk,
#    1457         is_read=is_read,
#    1458         session=session,
#    1459         read_pref=read_pref,
#    1460         address=address,
#    1461         retryable=retryable,
# -> 1462     ).run()
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pymongo/mongo_client.py:2315, in _ClientConnectionRetryable.run(self)
#    2313 self._check_last_error(check_csot=True)
#    2314 try:
# -> 2315     return self._read() if self._is_read else self._write()
#    2316 except ServerSelectionTimeoutError:
#    2317     # The application may think the write was never attempted
#    2318     # if we raise ServerSelectionTimeoutError on the retry
#    2319     # attempt. Raise the original exception instead.
#    2320     self._check_last_error()
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pymongo/mongo_client.py:2423, in _ClientConnectionRetryable._write(self)
#    2421             self._check_last_error()
#    2422             self._retryable = False
# -> 2423         return self._func(self._session, conn, self._retryable)  # type: ignore
#    2424 except PyMongoError as exc:
#    2425     if not self._retryable:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pymongo/bulk.py:432, in _Bulk.execute_command.<locals>.retryable_bulk(session, conn, retryable)
#     429 def retryable_bulk(
#     430     session: Optional[ClientSession], conn: Connection, retryable: bool
#     431 ) -> None:
# --> 432     self._execute_command(
#     433         generator,
#     434         write_concern,
#     435         session,
#     436         conn,
#     437         op_id,
#     438         retryable,
#     439         full_result,
#     440     )
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pymongo/bulk.py:378, in _Bulk._execute_command(self, generator, write_concern, session, conn, op_id, retryable, full_result, final_write_concern)
#     376 # Run as many ops as possible in one command.
#     377 if write_concern.acknowledged:
# --> 378     result, to_send = bwc.execute(cmd, ops, client)
#     380     # Retryable writeConcernErrors halt the execution of this run.
#     381     wce = result.get("writeConcernError", {})
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pymongo/message.py:964, in _BulkWriteContext.execute(self, cmd, docs, client)
#     960 def execute(
#     961     self, cmd: MutableMapping[str, Any], docs: list[Mapping[str, Any]], client: MongoClient
#     962 ) -> tuple[Mapping[str, Any], list[Mapping[str, Any]]]:
#     963     request_id, msg, to_send = self.__batch_command(cmd, docs)
# --> 964     result = self.write_command(cmd, request_id, msg, to_send)
#     965     client._process_response(result, self.session)
#     966     return result, to_send
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pymongo/helpers.py:322, in _handle_reauth.<locals>.inner(*args, **kwargs)
#     319 from pymongo.pool import Connection
#     321 try:
# --> 322     return func(*args, **kwargs)
#     323 except OperationFailure as exc:
#     324     if no_reauth:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pymongo/message.py:1058, in _BulkWriteContext.write_command(self, cmd, request_id, msg, docs)
#    1056     start = datetime.datetime.now()
#    1057 try:
# -> 1058     reply = self.conn.write_command(request_id, msg, self.codec)
#    1059     if self.publish:
#    1060         duration = (datetime.datetime.now() - start) + duration
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pymongo/pool.py:1060, in Connection.write_command(self, request_id, msg, codec_options)
#    1057 result = reply.command_response(codec_options)
#    1059 # Raises NotPrimaryError or OperationFailure.
# -> 1060 helpers._check_command_response(result, self.max_wire_version)
#    1061 return result
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pymongo/helpers.py:230, in _check_command_response(response, max_wire_version, allowable_errors, parse_write_concern_error)
#     227 elif code == 43:
#     228     raise CursorNotFound(errmsg, code, response, max_wire_version)
# --> 230 raise OperationFailure(errmsg, code, response, max_wire_version)
#
# OperationFailure: you are over your space quota, using 520 MB of 512 MB, full error: {'ok': 0, 'errmsg': 'you are over your space quota, using 520 MB of 512 MB', 'code': 8000, 'codeName': 'AtlasError'}

# %%
import os
from pymongo import MongoClient
import json

# Set up MongoDB Atlas connection URI
uri = os.environ.get('MONGODB_ATLAS_URI')
client = MongoClient(uri)

# Specify your database and collection
db = client['cluster0']  # Replace 'airbnb' with your database name if different
collection = db['airbnb']  # Replace 'airbnb' with your collection name

# Fetch all documents from the collection
data = collection.find({})

# Write data to a JSON file
with open('/Users/grantrobinett/2024/COE379L-Robinett/project4/airbnbData.json', 'w') as file:  # Specify the path to your local JSON file
    file.write('[')
    for index, document in enumerate(data):
        if index != 0:
            file.write(',')
        json.dump(document, file, default=str)  # Convert ObjectId and other BSON types to string
    file.write(']')

print("Data successfully written to JSON file.")
# Out:
# Data successfully written to JSON file.

# %% [markdown]
# # **START HERE**

# %%
import pandas as pd
import json

def load_json_subset(path):
    # Load the entire file into a JSON object
    with open(path, 'r') as file:
        data = json.load(file)  # Assuming the entire file is one large JSON array of objects

    # Convert only the first 'num_records' items to a DataFrame
    df = pd.DataFrame(data)
    return df

# Example usage
df = load_json_subset('/Users/grantrobinett/2024/COE379L-Robinett/project4/airbnbData.json')
print(df)
# Out:
#            _id                            listing_url  \
# 0     10006546  https://www.airbnb.com/rooms/10006546
# 1     10021707  https://www.airbnb.com/rooms/10021707
# 2      1001265   https://www.airbnb.com/rooms/1001265
# 3     10009999  https://www.airbnb.com/rooms/10009999
# 4     10047964  https://www.airbnb.com/rooms/10047964
# ...        ...                                    ...
# 5550   9795621   https://www.airbnb.com/rooms/9795621
# 5551   9834391   https://www.airbnb.com/rooms/9834391
# 5552   9721256   https://www.airbnb.com/rooms/9721256
# 5553   9849915   https://www.airbnb.com/rooms/9849915
# 5554   9908871   https://www.airbnb.com/rooms/9908871
#
#                                                   name  \
# 0                              Ribeira Charming Duplex
# 1                             Private Room in Bushwick
# 2                     Ocean View Waikiki Marina w/prkg
# 3                         Horto flat with small garden
# 4                       Charming Flat in Downtown Moda
# ...                                                ...
# 5550  Qto Aconchegante no em frente ao Parque Olímpico
# 5551  Lindo apto quarto e sala ao lado do mar de Copa!
# 5552                        Dover 42, Friendly Rentals
# 5553                           Magnificient Beach View
# 5554                       Family friendly beach house
#
#                                                 summary  \
# 0     Fantastic duplex apartment with three bedrooms...
# 1     Here exists a very cozy room for rent in a sha...
# 2     A short distance from Honolulu's billion dolla...
# 3     One bedroom + sofa-bed in quiet and bucolic ne...
# 4     Fully furnished 3+1 flat decorated with vintag...
# ...                                                 ...
# 5550  Apartamento em frente ao parque olímpico: sala...
# 5551  Lindo apartamento todo novinho, quarto (de cas...
# 5552  This apartment has: 4 single beds, 1 double so...
# 5553  Access to one of the best beaches in the world...
# 5554  Only 400 metres to the beach,2 x carparks,clos...
#
#                                                   space  \
# 0     Privileged views of the Douro River and Ribeir...
# 1
# 2     Great studio located on Ala Moana across the s...
# 3     Lovely one bedroom + sofa-bed in the living ro...
# 4     The apartment is composed of 1 big bedroom wit...
# ...                                                 ...
# 5550  Os hóspedes terão direito ao acesso às áreas c...
# 5551  Apto tem tudo o que o hóspede pode precisar, t...
# 5552  This apartment has: 4 single beds, 1 double so...
# 5553
# 5554
#
#                                             description  \
# 0     Fantastic duplex apartment with three bedrooms...
# 1     Here exists a very cozy room for rent in a sha...
# 2     A short distance from Honolulu's billion dolla...
# 3     One bedroom + sofa-bed in quiet and bucolic ne...
# 4     Fully furnished 3+1 flat decorated with vintag...
# ...                                                 ...
# 5550  Apartamento em frente ao parque olímpico: sala...
# 5551  Lindo apartamento todo novinho, quarto (de cas...
# 5552  This apartment has: 4 single beds, 1 double so...
# 5553  Access to one of the best beaches in the world...
# 5554  Only 400 metres to the beach,2 x carparks,clos...
#
#                                   neighborhood_overview  \
# 0     In the neighborhood of the river, you can find...
# 1
# 2                You can breath ocean as well as aloha.
# 3     This charming ground floor flat is located in ...
# 4     With its diversity Moda- Kadikoy is one of the...
# ...                                                 ...
# 5550  O Bairro possui bancos, mercados, farmácias, S...
# 5551  Staying at this apartment you will find everyt...
# 5552  EIXAMPLE ESQUERRA  (LEFT) This area  of the Ei...
# 5553
# 5554
#
#                                                   notes  \
# 0     Lose yourself in the narrow streets and stairc...
# 1
# 2
# 3     There´s a table in the living room now, that d...
# 4
# ...                                                 ...
# 5550
# 5551
# 5552
# 5553
# 5554
#
#                                                 transit  \
# 0     Transport: • Metro station and S. Bento railwa...
# 1
# 2     Honolulu does have a very good air conditioned...
# 3     Easy access to transport (bus, taxi, car) and ...
# 4
# ...                                                 ...
# 5550  O prédio fica ao lado de uma estação BRT de ôn...
# 5551  This apartment is located at the heart of Copa...
# 5552  Ideal to discover the city either on foot or b...
# 5553
# 5554
#
#                                                  access  ...  \
# 0     We are always available to help guests. The ho...  ...
# 1                                                        ...
# 2                              Pool, hot tub and tennis  ...
# 3                                                        ...
# 4                                                        ...
# ...                                                 ...  ...
# 5550  Os hóspedes terão acesso a cozinha, varanda, s...  ...
# 5551  You will have access to the whole apartment  a...  ...
# 5552  Travellers will have access to the entire apar...  ...
# 5553                                                     ...
# 5554                                                     ...
#
#                                                  images  \
# 0     {'thumbnail_url': '', 'medium_url': '', 'pictu...
# 1     {'thumbnail_url': '', 'medium_url': '', 'pictu...
# 2     {'thumbnail_url': '', 'medium_url': '', 'pictu...
# 3     {'thumbnail_url': '', 'medium_url': '', 'pictu...
# 4     {'thumbnail_url': '', 'medium_url': '', 'pictu...
# ...                                                 ...
# 5550  {'thumbnail_url': '', 'medium_url': '', 'pictu...
# 5551  {'thumbnail_url': '', 'medium_url': '', 'pictu...
# 5552  {'thumbnail_url': '', 'medium_url': '', 'pictu...
# 5553  {'thumbnail_url': '', 'medium_url': '', 'pictu...
# 5554  {'thumbnail_url': '', 'medium_url': '', 'pictu...
#
#                                                    host  \
# 0     {'host_id': '51399391', 'host_url': 'https://w...
# 1     {'host_id': '11275734', 'host_url': 'https://w...
# 2     {'host_id': '5448114', 'host_url': 'https://ww...
# 3     {'host_id': '1282196', 'host_url': 'https://ww...
# 4     {'host_id': '1241644', 'host_url': 'https://ww...
# ...                                                 ...
# 5550  {'host_id': '18967737', 'host_url': 'https://w...
# 5551  {'host_id': '1403065', 'host_url': 'https://ww...
# 5552  {'host_id': '136853', 'host_url': 'https://www...
# 5553  {'host_id': '12337597', 'host_url': 'https://w...
# 5554  {'host_id': '20914019', 'host_url': 'https://w...
#
#                                                 address  \
# 0     {'street': 'Porto, Porto, Portugal', 'suburb':...
# 1     {'street': 'Brooklyn, NY, United States', 'sub...
# 2     {'street': 'Honolulu, HI, United States', 'sub...
# 3     {'street': 'Rio de Janeiro, Rio de Janeiro, Br...
# 4     {'street': 'Kadıköy, İstanbul, Turkey', 'subur...
# ...                                                 ...
# 5550  {'street': 'Rio de Janeiro, Rio de Janeiro, Br...
# 5551  {'street': 'Rio de Janeiro, Rio de Janeiro, Br...
# 5552  {'street': 'Barcelona, Barcelona, Spain', 'sub...
# 5553  {'street': 'North Bondi, NSW, Australia', 'sub...
# 5554  {'street': 'North Bondi, NSW, Australia', 'sub...
#
#                                            availability  \
# 0     {'availability_30': 28, 'availability_60': 47,...
# 1     {'availability_30': 0, 'availability_60': 0, '...
# 2     {'availability_30': 16, 'availability_60': 46,...
# 3     {'availability_30': 0, 'availability_60': 0, '...
# 4     {'availability_30': 27, 'availability_60': 57,...
# ...                                                 ...
# 5550  {'availability_30': 23, 'availability_60': 50,...
# 5551  {'availability_30': 17, 'availability_60': 35,...
# 5552  {'availability_30': 14, 'availability_60': 19,...
# 5553  {'availability_30': 0, 'availability_60': 0, '...
# 5554  {'availability_30': 0, 'availability_60': 0, '...
#
#                                           review_scores  \
# 0     {'review_scores_accuracy': 9, 'review_scores_c...
# 1     {'review_scores_accuracy': 10, 'review_scores_...
# 2     {'review_scores_accuracy': 9, 'review_scores_c...
# 3     {'review_scores_accuracy': None, 'review_score...
# 4     {'review_scores_accuracy': 10, 'review_scores_...
# ...                                                 ...
# 5550  {'review_scores_accuracy': 10, 'review_scores_...
# 5551  {'review_scores_accuracy': 10, 'review_scores_...
# 5552  {'review_scores_accuracy': 9, 'review_scores_c...
# 5553  {'review_scores_accuracy': 10, 'review_scores_...
# 5554  {'review_scores_accuracy': None, 'review_score...
#
#                                                 reviews  weekly_price  \
# 0     [{'_id': '58663741', 'date': '2016-01-03 05:00...           NaN
# 1     [{'_id': '61050713', 'date': '2016-01-31 05:00...           NaN
# 2     [{'_id': '4765259', 'date': '2013-05-24 04:00:...         650.0
# 3                                                    []        1492.0
# 4     [{'_id': '68162172', 'date': '2016-04-02 04:00...           NaN
# ...                                                 ...           ...
# 5550  [{'_id': '196545684', 'date': '2017-09-23 04:0...           NaN
# 5551  [{'_id': '209162839', 'date': '2017-11-04 04:0...           NaN
# 5552  [{'_id': '57596654', 'date': '2015-12-27 05:00...           NaN
# 5553  [{'_id': '68460335', 'date': '2016-04-05 04:00...           NaN
# 5554                                                 []           NaN
#
#      monthly_price                                    text_embeddings  \
# 0              NaN  [0.0123710884, -0.0180913936, -0.016843712, -0...
# 1              NaN  [0.0153845912, -0.0348115042, -0.0093448907, 0...
# 2           2150.0  [-0.0400562622, -0.0405789167, 0.000644172, 0....
# 3           4849.0  [-0.063234821, 0.0017937823, -0.0243996996, -0...
# 4              NaN  [0.023723349, 0.0064210771, -0.0339970738, -0....
# ...            ...                                                ...
# 5550           NaN  [0.0355137363, 0.021601744, 0.0448862314, 0.04...
# 5551           NaN  [-0.0068668085, -0.003569406, -0.0056710192, 0...
# 5552           NaN  [-0.0075617288, 0.0177591294, 0.0368763767, 0....
# 5553           NaN  [0.0153845912, -0.0348115042, -0.0093448907, 0...
# 5554           NaN  [0.0153845912, -0.0348115042, -0.0093448907, 0...
#
#                                        image_embeddings
# 0     [-0.1302358955, 0.1534578055, 0.0199299306, -0...
# 1     [0.0340401195, 0.1742489338, -0.1572628617, 0....
# 2     [-0.1640156209, 0.1256971657, 0.6594450474, -0...
# 3     [-0.1292964518, 0.037789464, 0.2443587631, 0.0...
# 4     [-0.1006749049, 0.4022984803, -0.1821258366, 0...
# ...                                                 ...
# 5550  [0.1417888701, 0.4030978978, 0.1660289168, -0....
# 5551  [-0.107157357, 0.3447948098, 0.0107995747, 0.3...
# 5552                                               None
# 5553  [-0.3372063935, 0.5331305265, 0.1565771103, -0...
# 5554  [-0.0167170763, 0.3369778395, -0.2986375391, -...
#
# [5555 rows x 43 columns]

# %%
# List all column names in the DataFrame
column_names = df.columns.tolist()
print(column_names)
# Out:
# ['_id', 'listing_url', 'name', 'summary', 'space', 'description', 'neighborhood_overview', 'notes', 'transit', 'access', 'interaction', 'house_rules', 'property_type', 'room_type', 'bed_type', 'minimum_nights', 'maximum_nights', 'cancellation_policy', 'last_scraped', 'calendar_last_scraped', 'first_review', 'last_review', 'accommodates', 'bedrooms', 'beds', 'number_of_reviews', 'bathrooms', 'amenities', 'price', 'security_deposit', 'cleaning_fee', 'extra_people', 'guests_included', 'images', 'host', 'address', 'availability', 'review_scores', 'reviews', 'weekly_price', 'monthly_price', 'text_embeddings', 'image_embeddings']

# %%
# Print all unique values in the 'property_type' column
unique_property_types = df['property_type'].unique()
print(unique_property_types)

# %%
# Describe the DataFrame
df_description = df.describe()
print(df_description)

# %%
# Get type information for each column
df_info = df.info()
print(df_info)

# %%
import os
import json
import requests

def ensure_dir(directory):
    if not os.path.exists(directory):
        os.makedirs(directory)

def download_image(image_url, path_to_save):
    try:
        response = requests.get(image_url, stream=True, timeout=10)  # 10-second timeout
        if response.status_code == 200:
            with open(path_to_save, 'wb') as out_file:
                out_file.write(response.content)
            return True
    except requests.RequestException as e:
        print(f"Error downloading {image_url}: {e}")
    return False

def process_images(json_path, output_dir, log_file):
    with open(json_path, 'r') as file:
        listings = json.load(file)

    unsuccessful_ids = []

    for listing in listings:
        listing_id = listing['_id']
        images = listing.get('images', {})
        directory_path = os.path.join(output_dir, str(listing_id))
        ensure_dir(directory_path)

        success = False
        for key, url in images.items():
            if url:  # Check if the URL is not empty
                file_name = url.split('/')[-1].split('?')[0]  # Simplistic way to get file name from URL
                full_path = os.path.join(directory_path, file_name)
                if download_image(url, full_path):
                    print(f"Successfully downloaded {full_path}")
                    success = True
                else:
                    print(f"Failed to download from {url}")

        if not success:
            unsuccessful_ids.append(listing_id)

    # Log unsuccessful IDs
    if unsuccessful_ids:
        with open(log_file, 'w') as f:
            for id in unsuccessful_ids:
                f.write(f"{id}\n")
        print(f"Logged unsuccessful download IDs to {log_file}")

# Example usage
process_images('/Users/grantrobinett/2024/COE379L-Robinett/project4/airbnbData.json', 'imagesData', 'unsuccessful_downloads.log')

# %%
# Print how many folders are in imagesData
print(len(os.listdir('imagesData')))
# Out:
# 5555

# %%
# Remove folders in imagesData that are empty using the unsuccessful_downloads.log file. If there is an image in the folder, remove the image then remove the folder.
with open('unsuccessful_downloads.log', 'r') as file:
    unsuccessful_ids = file.read().splitlines()

for id in unsuccessful_ids:
    directory_path = os.path.join('imagesData', id)
    if os.path.exists(directory_path):
        if os.path.isdir(directory_path):
            if os.listdir(directory_path):
                for file in os.listdir(directory_path):
                    os.remove(os.path.join(directory_path, file))
            os.rmdir(directory_path)
        else:
            os.remove(directory_path)

# Print how many folders are in imagesData after removing empty folders
print(len(os.listdir('imagesData')))
# Out:
# 4611

# %% [markdown]
# # **START HERE OOPS**

# %%
import pandas as pd
import json
import os

def load_json_subset(path):
    # Load the entire file into a JSON object
    with open(path, 'r') as file:
        data = json.load(file)  # Assuming the entire file is one large JSON array of objects

    # Convert the data to a DataFrame
    df = pd.DataFrame(data)
    return df

# Load the DataFrame
df = load_json_subset('/Users/grantrobinett/2024/COE379L-Robinett/project4/airbnbData.json')
print(f"Original DataFrame size: {df.shape}")

# Load unsuccessful IDs from log file
with open('unsuccessful_downloads.log', 'r') as file:
    unsuccessful_ids = file.read().splitlines()

# Convert unsuccessful_ids to the correct data type if necessary
unsuccessful_ids = [int(id) for id in unsuccessful_ids]  # Convert to int if IDs are integers

# Filter the DataFrame
filter_df = df[~df['_id'].isin(unsuccessful_ids)]
print(f"Filtered DataFrame size: {filter_df.shape}")

# Remove folders and files for unsuccessful IDs
for id in unsuccessful_ids:
    directory_path = os.path.join('imagesData', str(id))  # Ensure the path uses str(id) if needed
    if os.path.exists(directory_path) and os.path.isdir(directory_path):
        for file in os.listdir(directory_path):
            os.remove(os.path.join(directory_path, file))
        os.rmdir(directory_path)

# Count remaining folders
remaining_folders = len(os.listdir('imagesData'))
print(f"Number of remaining folders in 'imagesData': {remaining_folders}")
# Out:
# Original DataFrame size: (5555, 43)
# Filtered DataFrame size: (4610, 43)
# Number of remaining folders in 'imagesData': 4611

# %%
# Print 'reviews' column from the first 5 rows of the filtered DataFrame
print(filter_df['summary'].head())
# Print keys of the first row in the 'reviews' column
print(filter_df['summary'][0])
print(filter_df['summary'][1])
# Out:
# 0    Fantastic duplex apartment with three bedrooms...
# 1    Here exists a very cozy room for rent in a sha...
# 2    A short distance from Honolulu's billion dolla...
# 3    One bedroom + sofa-bed in quiet and bucolic ne...
# 4    Fully furnished 3+1 flat decorated with vintag...
# Name: summary, dtype: object
# Fantastic duplex apartment with three bedrooms, located in the historic area of Porto, Ribeira (Cube) - UNESCO World Heritage Site. Centenary building fully rehabilitated, without losing their original character.
# Here exists a very cozy room for rent in a shared 4-bedroom apartment. It is located one block off of the JMZ at Myrtle Broadway.  The neighborhood is diverse and appeals to a variety of people.

# %%
# Print 'reviews' column from the first 5 rows of the filtered DataFrame
print(filter_df['space'].head())

# Print keys of the first row in the 'reviews' column
print(filter_df['space'][0])
# Out:
# 0    Privileged views of the Douro River and Ribeir...
# 1
# 2    Great studio located on Ala Moana across the s...
# 3    Lovely one bedroom + sofa-bed in the living ro...
# 4    The apartment is composed of 1 big bedroom wit...
# Name: space, dtype: object
# Privileged views of the Douro River and Ribeira square, our apartment offers the perfect conditions to discover the history and the charm of Porto. Apartment comfortable, charming, romantic and cozy in the heart of Ribeira. Within walking distance of all the most emblematic places of the city of Porto. The apartment is fully equipped to host 8 people, with cooker, oven, washing machine, dishwasher, microwave, coffee machine (Nespresso) and kettle. The apartment is located in a very typical area of the city that allows to cross with the most picturesque population of the city, welcoming, genuine and happy people that fills the streets with his outspoken speech and contagious with your sincere generosity, wrapped in a only parochial spirit.
# Here exists a very cozy room for rent in a shared 4-bedroom apartment. It is located one block off of the JMZ at Myrtle Broadway.  The neighborhood is diverse and appeals to a variety of people.

# %%
# Print 'reviews' column from the first 5 rows of the filtered DataFrame
print(filter_df['description'].head())

# Print keys of the first row in the 'reviews' column
print(filter_df['description'][0])
# Out:
# 0    Fantastic duplex apartment with three bedrooms...
# 1    Here exists a very cozy room for rent in a sha...
# 2    A short distance from Honolulu's billion dolla...
# 3    One bedroom + sofa-bed in quiet and bucolic ne...
# 4    Fully furnished 3+1 flat decorated with vintag...
# Name: description, dtype: object
# Fantastic duplex apartment with three bedrooms, located in the historic area of Porto, Ribeira (Cube) - UNESCO World Heritage Site. Centenary building fully rehabilitated, without losing their original character. Privileged views of the Douro River and Ribeira square, our apartment offers the perfect conditions to discover the history and the charm of Porto. Apartment comfortable, charming, romantic and cozy in the heart of Ribeira. Within walking distance of all the most emblematic places of the city of Porto. The apartment is fully equipped to host 8 people, with cooker, oven, washing machine, dishwasher, microwave, coffee machine (Nespresso) and kettle. The apartment is located in a very typical area of the city that allows to cross with the most picturesque population of the city, welcoming, genuine and happy people that fills the streets with his outspoken speech and contagious with your sincere generosity, wrapped in a only parochial spirit. We are always available to help guests

# %% [markdown]
# # Data Loaded, Images Processed, we are cooking

# %%
# Using filtered Data Now
# categorical columns and possible values

# List all column names in the DataFrame
column_names = filter_df.columns.tolist()
print(column_names)
# Out:
# ['_id', 'listing_url', 'name', 'summary', 'space', 'description', 'neighborhood_overview', 'notes', 'transit', 'access', 'interaction', 'house_rules', 'property_type', 'room_type', 'bed_type', 'minimum_nights', 'maximum_nights', 'cancellation_policy', 'last_scraped', 'calendar_last_scraped', 'first_review', 'last_review', 'accommodates', 'bedrooms', 'beds', 'number_of_reviews', 'bathrooms', 'amenities', 'price', 'security_deposit', 'cleaning_fee', 'extra_people', 'guests_included', 'images', 'host', 'address', 'availability', 'review_scores', 'reviews', 'weekly_price', 'monthly_price', 'text_embeddings', 'image_embeddings']

# %%
# Print a row of review_scores
review_scores = filter_df['review_scores'].head()
# Print keys of the first review_scores dictionary
review_scores_keys = review_scores[0].keys()
print(review_scores_keys)
# Print dictionary key 'review_scores_rating' of review_scores[0]
review_scores_rating = review_scores[0]['review_scores_rating']
print(review_scores_rating)
# Out:
# dict_keys(['review_scores_accuracy', 'review_scores_cleanliness', 'review_scores_checkin', 'review_scores_communication', 'review_scores_location', 'review_scores_value', 'review_scores_rating'])
# 89

# %% [markdown]
# # It is time for us to select what columns we would like to use for our machine learning
# We chose:
# - property_type
# - room_type
# - bed_type
# - bedrooms
# - accommodates
# - beds
# - bathroooms
# - review_scores_rating
#
# For multi-modal possibilities (extra if we can)
# - summary [sentiment analysis]
# - description [sentiment]
# - notes [sentiment]

# %%
# Print unique values in the 'property_type' column
unique_property_types = filter_df['property_type'].unique()
print("Property Types:\n",unique_property_types)

# Print unique values in the 'room_type' column
unique_room_types = filter_df['room_type'].unique()
print("Room Types:\n",unique_room_types)

# Print unique values in the 'bed_type' column
unique_bed_types = filter_df['bed_type'].unique()
print("Bed Types:\n",unique_bed_types)

# Print unique values in the 'bedrooms' column
unique_bedrooms = filter_df['bedrooms'].unique()
print("Bedrooms:\n",unique_bedrooms)

# Print unique values in the 'accommodates' column
unique_accommodates = filter_df['accommodates'].unique()
print("Accommodates:\n",unique_accommodates)

# Print unique values in the 'beds' column
unique_beds = filter_df['beds'].unique()
print("Beds:\n",unique_beds)

# Print unique values in the 'bathrooms' column
unique_bathrooms = filter_df['bathrooms'].unique()
print("Bathrooms:\n",unique_bathrooms)

# # Print unique values in the 'review_scores' column
# unique_review_scores = filter_df['review_scores'].unique()
# print("Review Scores:\n",unique_review_scores)

# %%
# Check all columns for NaN values
nan_values = filter_df.isna().sum()
print(nan_values)
# Out:
# _id                         0
# listing_url                 0
# name                        0
# summary                     0
# space                       0
# description                 0
# neighborhood_overview       0
# notes                       0
# transit                     0
# access                      0
# interaction                 0
# house_rules                 0
# property_type               0
# room_type                   0
# bed_type                    0
# minimum_nights              0
# maximum_nights              0
# cancellation_policy         0
# last_scraped                0
# calendar_last_scraped       0
# first_review             1186
# last_review              1186
# accommodates                0
# bedrooms                    5
# beds                       13
# number_of_reviews           0
# bathrooms                  10
# amenities                   0
# price                       0
# security_deposit         1820
# cleaning_fee             1359
# extra_people                0
# guests_included             0
# images                      0
# host                        0
# address                     0
# availability                0
# review_scores               0
# reviews                     0
# weekly_price             3973
# monthly_price            4038
# text_embeddings             0
# image_embeddings            0
# dtype: int64

# %%
import pandas as pd
import numpy as np

# Define a function to safely extract review_scores_rating
def get_review_scores_rating(review_scores):
    if pd.isna(review_scores):
        return np.nan
    return review_scores.get('review_scores_rating', np.nan)

# Define a function to safely extract review_scores_value
def get_review_scores_value(review_scores):
    if pd.isna(review_scores):
        return np.nan
    return review_scores.get('review_scores_value', np.nan)

# Apply this function to the 'review_scores' column
filter_df['review_scores_rating'] = filter_df['review_scores'].apply(get_review_scores_rating)
filter_df['review_scores_value'] = filter_df['review_scores'].apply(get_review_scores_value)



# Add 'review_scores_rating' to the columns list
columns_used = ['_id', 'name', 'summary', 'description', 'neighborhood_overview', 'notes', 
                'property_type', 'room_type', 'accommodates', 'bedrooms', 'beds', 
                'bathrooms', 'bed_type', 'amenities', 'price', 'review_scores_rating', 'review_scores_value', 'number_of_reviews']
filter_df = filter_df[columns_used]

# Check all columns for NaN values
nan_values = filter_df.isna().sum()
print(nan_values)

# Drop rows with NaN values
filter_df = filter_df.dropna()

# Check all columns for NaN values
nan_values = filter_df.isna().sum()
print(nan_values)
# Out:
# _id                         0
# name                        0
# summary                     0
# description                 0
# neighborhood_overview       0
# notes                       0
# property_type               0
# room_type                   0
# accommodates                0
# bedrooms                    5
# beds                       13
# bathrooms                  10
# bed_type                    0
# amenities                   0
# price                       0
# review_scores_rating     1266
# review_scores_value      1266
# number_of_reviews           0
# dtype: int64
# _id                      0
# name                     0
# summary                  0
# description              0
# neighborhood_overview    0
# notes                    0
# property_type            0
# room_type                0
# accommodates             0
# bedrooms                 0
# beds                     0
# bathrooms                0
# bed_type                 0
# amenities                0
# price                    0
# review_scores_rating     0
# review_scores_value      0
# number_of_reviews        0
# dtype: int64
# /var/folders/r1/x17z5wq913s3rgkc6t0y_m0h0000gn/T/ipykernel_5105/568142089.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filter_df['review_scores_rating'] = filter_df['review_scores'].apply(get_review_scores_rating)
# /var/folders/r1/x17z5wq913s3rgkc6t0y_m0h0000gn/T/ipykernel_5105/568142089.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filter_df['review_scores_value'] = filter_df['review_scores'].apply(get_review_scores_value)

# %%
# All good to go. Let's start with the data preprocessing.
# First, let's check the data types of each column.
data_types = filter_df.dtypes
print(data_types)
# Out:
# _id                        int64
# name                      object
# summary                   object
# description               object
# neighborhood_overview     object
# notes                     object
# property_type             object
# room_type                 object
# accommodates               int64
# bedrooms                 float64
# beds                     float64
# bathrooms                float64
# bed_type                  object
# amenities                 object
# price                      int64
# review_scores_rating     float64
# review_scores_value      float64
# number_of_reviews          int64
# dtype: object

# %%
import matplotlib.pyplot as plt

# Plot training & validation loss values
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='upper right')
plt.show()

# %%
# Now, save the model using tf serving
# Save the model
model.save('models/NN_18_bert', save_format='tf')
# Out:
# INFO:tensorflow:Assets written to: models/NN_18_bert/assets
# INFO:tensorflow:Assets written to: models/NN_18_bert/assets

# %% [markdown]
# # Credit chatGPT for helping us interperet the SCALED values back to usd.

# %%
from joblib import load

# Load the scaler
scaler = load('scaler_numerical.joblib')

import tensorflow as tf

# Load the trained model
model = tf.keras.models.load_model('models/NN_18_bert')

# Assuming model and X_test are already loaded and prepared
predictions_scaled = model.predict(X_test)

import numpy as np

# Create an array of zeros with the same shape as the input features
dummy_data = np.zeros(shape=(predictions_scaled.shape[0], len(numerical_columns)))

# Assuming 'price' is the last column in the numerical_columns list
# Place the predicted values in the correct column index for 'price'
price_index = numerical_columns.index('price')
dummy_data[:, price_index] = predictions_scaled.flatten()  # Flatten to ensure correct shape

# Load the saved scaler
scaler = load('scaler_numerical.joblib')

# Inverse transform the dummy dataset
predictions_unscaled = scaler.inverse_transform(dummy_data)[:, price_index]

# Prepare dummy data for y_test
dummy_y_test = np.zeros(shape=(len(y_test), len(numerical_columns)))

# Convert y_test to a numpy array and reshape appropriately
# Ensure y_test is reshaped correctly to match the dummy array structure
dummy_y_test[:, price_index] = y_test.to_numpy().reshape(-1)

# Inverse transform y_test using the fitted scaler
scaler = load('scaler_numerical.joblib')
actual_prices = scaler.inverse_transform(dummy_y_test)[:, price_index]

# Print predicted and actual prices
for pred, actual in zip(predictions_unscaled, actual_prices):
    print(f"Predicted Price: ${pred:.2f}, Actual Price: ${actual:.2f}")
# Out:
# 19/19 [==============================] - 0s 2ms/step
# Predicted Price: $93.72, Actual Price: $68.00
# Predicted Price: $109.67, Actual Price: $110.00
# Predicted Price: $94.71, Actual Price: $95.00
# Predicted Price: $118.76, Actual Price: $125.00
# Predicted Price: $92.47, Actual Price: $35.00
# Predicted Price: $92.11, Actual Price: $72.00
# Predicted Price: $158.76, Actual Price: $145.00
# Predicted Price: $103.74, Actual Price: $40.00
# Predicted Price: $104.14, Actual Price: $90.00
# Predicted Price: $93.71, Actual Price: $35.00
# Predicted Price: $209.49, Actual Price: $140.00
# Predicted Price: $119.46, Actual Price: $58.00
# Predicted Price: $114.45, Actual Price: $250.00
# Predicted Price: $92.30, Actual Price: $110.00
# Predicted Price: $92.14, Actual Price: $105.00
# Predicted Price: $130.93, Actual Price: $200.00
# Predicted Price: $98.91, Actual Price: $205.00
# Predicted Price: $137.46, Actual Price: $353.00
# Predicted Price: $104.94, Actual Price: $25.00
# Predicted Price: $111.86, Actual Price: $129.00
# Predicted Price: $91.34, Actual Price: $79.00
# Predicted Price: $122.87, Actual Price: $237.00
# Predicted Price: $124.58, Actual Price: $250.00
# Predicted Price: $92.14, Actual Price: $447.00
# Predicted Price: $95.58, Actual Price: $201.00
# Predicted Price: $128.34, Actual Price: $60.00
# Predicted Price: $258.58, Actual Price: $353.00
# Predicted Price: $148.37, Actual Price: $243.00
# Predicted Price: $175.61, Actual Price: $200.00
# Predicted Price: $99.66, Actual Price: $225.00
# Predicted Price: $115.06, Actual Price: $251.00
# Predicted Price: $223.35, Actual Price: $275.00
# Predicted Price: $106.72, Actual Price: $101.00
# Predicted Price: $108.62, Actual Price: $261.00
# Predicted Price: $108.60, Actual Price: $80.00
# Predicted Price: $151.23, Actual Price: $115.00
# Predicted Price: $91.69, Actual Price: $44.00
# Predicted Price: $108.94, Actual Price: $160.00
# Predicted Price: $120.01, Actual Price: $85.00
# Predicted Price: $135.76, Actual Price: $100.00
# Predicted Price: $92.52, Actual Price: $25.00
# Predicted Price: $111.53, Actual Price: $45.00
# Predicted Price: $106.18, Actual Price: $125.00
# Predicted Price: $97.50, Actual Price: $80.00
# Predicted Price: $144.78, Actual Price: $200.00
# Predicted Price: $96.36, Actual Price: $65.00
# Predicted Price: $117.37, Actual Price: $56.00
# Predicted Price: $93.07, Actual Price: $129.00
# Predicted Price: $112.91, Actual Price: $49.00
# Predicted Price: $91.93, Actual Price: $40.00
# Predicted Price: $96.07, Actual Price: $86.00
# Predicted Price: $178.94, Actual Price: $380.00
# Predicted Price: $97.23, Actual Price: $45.00
# Predicted Price: $111.90, Actual Price: $120.00
# Predicted Price: $181.38, Actual Price: $351.00
# Predicted Price: $102.11, Actual Price: $40.00
# Predicted Price: $92.77, Actual Price: $68.00
# Predicted Price: $104.55, Actual Price: $89.00
# Predicted Price: $124.49, Actual Price: $68.00
# Predicted Price: $112.81, Actual Price: $195.00
# Predicted Price: $126.33, Actual Price: $40.00
# Predicted Price: $102.73, Actual Price: $108.00
# Predicted Price: $126.32, Actual Price: $140.00
# Predicted Price: $168.10, Actual Price: $350.00
# Predicted Price: $151.69, Actual Price: $175.00
# Predicted Price: $140.91, Actual Price: $189.00
# Predicted Price: $96.39, Actual Price: $30.00
# Predicted Price: $92.36, Actual Price: $35.00
# Predicted Price: $98.24, Actual Price: $24.00
# Predicted Price: $154.77, Actual Price: $31.00
# Predicted Price: $102.67, Actual Price: $120.00
# Predicted Price: $92.46, Actual Price: $400.00
# Predicted Price: $100.43, Actual Price: $185.00
# Predicted Price: $102.30, Actual Price: $50.00
# Predicted Price: $119.77, Actual Price: $169.00
# Predicted Price: $103.10, Actual Price: $15.00
# Predicted Price: $264.89, Actual Price: $450.00
# Predicted Price: $107.16, Actual Price: $261.00
# Predicted Price: $109.60, Actual Price: $115.00
# Predicted Price: $174.29, Actual Price: $198.00
# Predicted Price: $116.67, Actual Price: $35.00
# Predicted Price: $110.29, Actual Price: $75.00
# Predicted Price: $98.80, Actual Price: $119.00
# Predicted Price: $103.16, Actual Price: $95.00
# Predicted Price: $105.92, Actual Price: $69.00
# Predicted Price: $171.93, Actual Price: $189.00
# Predicted Price: $102.29, Actual Price: $246.00
# Predicted Price: $147.37, Actual Price: $64.00
# Predicted Price: $91.60, Actual Price: $26.00
# Predicted Price: $117.33, Actual Price: $90.00
# Predicted Price: $94.21, Actual Price: $101.00
# Predicted Price: $112.76, Actual Price: $37.00
# Predicted Price: $94.00, Actual Price: $139.00
# Predicted Price: $122.30, Actual Price: $75.00
# Predicted Price: $192.41, Actual Price: $298.00
# Predicted Price: $132.72, Actual Price: $158.00
# Predicted Price: $220.83, Actual Price: $150.00
# Predicted Price: $93.74, Actual Price: $40.00
# Predicted Price: $120.27, Actual Price: $51.00
# Predicted Price: $101.87, Actual Price: $400.00
# Predicted Price: $100.20, Actual Price: $59.00
# Predicted Price: $110.98, Actual Price: $125.00
# Predicted Price: $159.12, Actual Price: $192.00
# Predicted Price: $133.60, Actual Price: $298.00
# Predicted Price: $167.55, Actual Price: $180.00
# Predicted Price: $101.28, Actual Price: $138.00
# Predicted Price: $92.88, Actual Price: $48.00
# Predicted Price: $122.74, Actual Price: $159.00
# Predicted Price: $101.19, Actual Price: $40.00
# Predicted Price: $91.57, Actual Price: $63.00
# Predicted Price: $91.89, Actual Price: $150.00
# Predicted Price: $102.58, Actual Price: $154.00
# Predicted Price: $122.42, Actual Price: $174.00
# Predicted Price: $91.64, Actual Price: $424.00
# Predicted Price: $136.19, Actual Price: $189.00
# Predicted Price: $129.58, Actual Price: $348.00
# Predicted Price: $91.86, Actual Price: $65.00
# Predicted Price: $148.09, Actual Price: $150.00
# Predicted Price: $91.88, Actual Price: $135.00
# Predicted Price: $136.14, Actual Price: $262.00
# Predicted Price: $119.94, Actual Price: $231.00
# Predicted Price: $161.62, Actual Price: $220.00
# Predicted Price: $198.11, Actual Price: $149.00
# Predicted Price: $92.13, Actual Price: $75.00
# Predicted Price: $204.39, Actual Price: $275.00
# Predicted Price: $105.87, Actual Price: $90.00
# Predicted Price: $116.99, Actual Price: $85.00
# Predicted Price: $123.51, Actual Price: $270.00
# Predicted Price: $132.98, Actual Price: $42.00
# Predicted Price: $91.80, Actual Price: $59.00
# Predicted Price: $133.38, Actual Price: $300.00
# Predicted Price: $91.98, Actual Price: $27.00
# Predicted Price: $119.08, Actual Price: $151.00
# Predicted Price: $92.94, Actual Price: $45.00
# Predicted Price: $94.35, Actual Price: $359.00
# Predicted Price: $94.79, Actual Price: $25.00
# Predicted Price: $104.48, Actual Price: $55.00
# Predicted Price: $101.79, Actual Price: $80.00
# Predicted Price: $94.54, Actual Price: $95.00
# Predicted Price: $108.00, Actual Price: $160.00
# Predicted Price: $91.90, Actual Price: $212.00
# Predicted Price: $91.67, Actual Price: $95.00
# Predicted Price: $96.98, Actual Price: $55.00
# Predicted Price: $104.37, Actual Price: $60.00
# Predicted Price: $109.38, Actual Price: $48.00
# Predicted Price: $108.97, Actual Price: $75.00
# Predicted Price: $120.48, Actual Price: $52.00
# Predicted Price: $103.16, Actual Price: $70.00
# Predicted Price: $92.14, Actual Price: $119.00
# Predicted Price: $100.90, Actual Price: $60.00
# Predicted Price: $99.13, Actual Price: $100.00
# Predicted Price: $122.00, Actual Price: $500.00
# Predicted Price: $129.16, Actual Price: $82.00
# Predicted Price: $107.67, Actual Price: $86.00
# Predicted Price: $93.10, Actual Price: $63.00
# Predicted Price: $119.93, Actual Price: $67.00
# Predicted Price: $129.16, Actual Price: $295.00
# Predicted Price: $113.13, Actual Price: $95.00
# Predicted Price: $91.90, Actual Price: $40.00
# Predicted Price: $185.84, Actual Price: $310.00
# Predicted Price: $124.81, Actual Price: $151.00
# Predicted Price: $93.96, Actual Price: $45.00
# Predicted Price: $119.94, Actual Price: $105.00
# Predicted Price: $150.58, Actual Price: $50.00
# Predicted Price: $117.65, Actual Price: $60.00
# Predicted Price: $98.43, Actual Price: $79.00
# Predicted Price: $94.65, Actual Price: $121.00
# Predicted Price: $112.25, Actual Price: $400.00
# Predicted Price: $102.33, Actual Price: $78.00
# Predicted Price: $103.80, Actual Price: $25.00
# Predicted Price: $93.91, Actual Price: $65.00
# Predicted Price: $96.48, Actual Price: $129.00
# Predicted Price: $103.88, Actual Price: $40.00
# Predicted Price: $91.57, Actual Price: $40.00
# Predicted Price: $92.50, Actual Price: $100.00
# Predicted Price: $94.22, Actual Price: $50.00
# Predicted Price: $129.56, Actual Price: $60.00
# Predicted Price: $112.27, Actual Price: $451.00
# Predicted Price: $96.38, Actual Price: $32.00
# Predicted Price: $92.27, Actual Price: $204.00
# Predicted Price: $140.14, Actual Price: $301.00
# Predicted Price: $106.21, Actual Price: $250.00
# Predicted Price: $92.58, Actual Price: $60.00
# Predicted Price: $103.74, Actual Price: $95.00
# Predicted Price: $104.21, Actual Price: $500.00
# Predicted Price: $92.02, Actual Price: $224.00
# Predicted Price: $93.03, Actual Price: $73.00
# Predicted Price: $93.68, Actual Price: $45.00
# Predicted Price: $93.54, Actual Price: $70.00
# Predicted Price: $117.56, Actual Price: $200.00
# Predicted Price: $92.09, Actual Price: $70.00
# Predicted Price: $183.01, Actual Price: $449.00
# Predicted Price: $151.73, Actual Price: $157.00
# Predicted Price: $91.94, Actual Price: $74.00
# Predicted Price: $94.42, Actual Price: $101.00
# Predicted Price: $115.69, Actual Price: $65.00
# Predicted Price: $92.84, Actual Price: $30.00
# Predicted Price: $129.17, Actual Price: $85.00
# Predicted Price: $102.38, Actual Price: $348.00
# Predicted Price: $99.80, Actual Price: $85.00
# Predicted Price: $106.18, Actual Price: $175.00
# Predicted Price: $93.92, Actual Price: $99.00
# Predicted Price: $91.90, Actual Price: $78.00
# Predicted Price: $148.04, Actual Price: $500.00
# Predicted Price: $116.65, Actual Price: $127.00
# Predicted Price: $138.43, Actual Price: $264.00
# Predicted Price: $109.05, Actual Price: $139.00
# Predicted Price: $92.63, Actual Price: $120.00
# Predicted Price: $115.71, Actual Price: $20.00
# Predicted Price: $92.79, Actual Price: $45.00
# Predicted Price: $105.04, Actual Price: $461.00
# Predicted Price: $132.95, Actual Price: $159.00
# Predicted Price: $116.00, Actual Price: $225.00
# Predicted Price: $112.73, Actual Price: $81.00
# Predicted Price: $97.50, Actual Price: $70.00
# Predicted Price: $108.85, Actual Price: $161.00
# Predicted Price: $92.35, Actual Price: $98.00
# Predicted Price: $150.52, Actual Price: $160.00
# Predicted Price: $104.41, Actual Price: $209.00
# Predicted Price: $100.01, Actual Price: $80.00
# Predicted Price: $92.04, Actual Price: $60.00
# Predicted Price: $97.60, Actual Price: $75.00
# Predicted Price: $122.93, Actual Price: $60.00
# Predicted Price: $132.19, Actual Price: $277.00
# Predicted Price: $108.59, Actual Price: $70.00
# Predicted Price: $112.55, Actual Price: $97.00
# Predicted Price: $123.28, Actual Price: $290.00
# Predicted Price: $115.49, Actual Price: $140.00
# Predicted Price: $120.11, Actual Price: $250.00
# Predicted Price: $92.47, Actual Price: $300.00
# Predicted Price: $92.13, Actual Price: $60.00
# Predicted Price: $152.27, Actual Price: $120.00
# Predicted Price: $92.96, Actual Price: $190.00
# Predicted Price: $156.01, Actual Price: $84.00
# Predicted Price: $92.29, Actual Price: $120.00
# Predicted Price: $123.78, Actual Price: $90.00
# Predicted Price: $98.43, Actual Price: $250.00
# Predicted Price: $124.05, Actual Price: $70.00
# Predicted Price: $101.75, Actual Price: $70.00
# Predicted Price: $203.15, Actual Price: $140.00
# Predicted Price: $112.25, Actual Price: $70.00
# Predicted Price: $128.26, Actual Price: $99.00
# Predicted Price: $129.40, Actual Price: $181.00
# Predicted Price: $101.27, Actual Price: $80.00
# Predicted Price: $92.71, Actual Price: $47.00
# Predicted Price: $101.46, Actual Price: $78.00
# Predicted Price: $93.00, Actual Price: $80.00
# Predicted Price: $91.90, Actual Price: $60.00
# Predicted Price: $91.89, Actual Price: $45.00
# Predicted Price: $96.05, Actual Price: $50.00
# Predicted Price: $107.93, Actual Price: $455.00
# Predicted Price: $92.30, Actual Price: $424.00
# Predicted Price: $140.94, Actual Price: $79.00
# Predicted Price: $128.86, Actual Price: $125.00
# Predicted Price: $92.99, Actual Price: $28.00
# Predicted Price: $125.44, Actual Price: $264.00
# Predicted Price: $91.76, Actual Price: $48.00
# Predicted Price: $100.58, Actual Price: $60.00
# Predicted Price: $107.61, Actual Price: $96.00
# Predicted Price: $171.83, Actual Price: $160.00
# Predicted Price: $116.49, Actual Price: $43.00
# Predicted Price: $94.25, Actual Price: $400.00
# Predicted Price: $144.89, Actual Price: $119.00
# Predicted Price: $92.35, Actual Price: $84.00
# Predicted Price: $224.96, Actual Price: $338.00
# Predicted Price: $144.44, Actual Price: $260.00
# Predicted Price: $110.40, Actual Price: $200.00
# Predicted Price: $100.34, Actual Price: $280.00
# Predicted Price: $217.61, Actual Price: $417.00
# Predicted Price: $101.48, Actual Price: $129.00
# Predicted Price: $100.14, Actual Price: $101.00
# Predicted Price: $133.44, Actual Price: $399.00
# Predicted Price: $132.98, Actual Price: $132.00
# Predicted Price: $99.43, Actual Price: $86.00
# Predicted Price: $123.41, Actual Price: $161.00
# Predicted Price: $95.45, Actual Price: $110.00
# Predicted Price: $115.23, Actual Price: $50.00
# Predicted Price: $118.54, Actual Price: $90.00
# Predicted Price: $100.83, Actual Price: $447.00
# Predicted Price: $110.17, Actual Price: $99.00
# Predicted Price: $150.72, Actual Price: $351.00
# Predicted Price: $99.23, Actual Price: $248.00
# Predicted Price: $113.77, Actual Price: $194.00
# Predicted Price: $143.47, Actual Price: $128.00
# Predicted Price: $92.51, Actual Price: $15.00
# Predicted Price: $185.93, Actual Price: $343.00
# Predicted Price: $167.59, Actual Price: $228.00
# Predicted Price: $129.76, Actual Price: $385.00
# Predicted Price: $111.98, Actual Price: $115.00
# Predicted Price: $116.77, Actual Price: $34.00
# Predicted Price: $98.26, Actual Price: $90.00
# Predicted Price: $91.90, Actual Price: $15.00
# Predicted Price: $106.81, Actual Price: $99.00
# Predicted Price: $96.05, Actual Price: $87.00
# Predicted Price: $114.77, Actual Price: $38.00
# Predicted Price: $98.26, Actual Price: $400.00
# Predicted Price: $106.97, Actual Price: $139.00
# Predicted Price: $108.14, Actual Price: $60.00
# Predicted Price: $130.06, Actual Price: $220.00
# Predicted Price: $111.69, Actual Price: $55.00
# Predicted Price: $92.11, Actual Price: $60.00
# Predicted Price: $92.85, Actual Price: $85.00
# Predicted Price: $105.37, Actual Price: $243.00
# Predicted Price: $92.87, Actual Price: $251.00
# Predicted Price: $140.45, Actual Price: $86.00
# Predicted Price: $98.16, Actual Price: $50.00
# Predicted Price: $92.26, Actual Price: $47.00
# Predicted Price: $129.37, Actual Price: $175.00
# Predicted Price: $101.14, Actual Price: $35.00
# Predicted Price: $113.18, Actual Price: $69.00
# Predicted Price: $92.06, Actual Price: $119.00
# Predicted Price: $100.64, Actual Price: $66.00
# Predicted Price: $116.28, Actual Price: $52.00
# Predicted Price: $184.80, Actual Price: $328.00
# Predicted Price: $103.10, Actual Price: $130.00
# Predicted Price: $111.82, Actual Price: $169.00
# Predicted Price: $109.48, Actual Price: $100.00
# Predicted Price: $91.83, Actual Price: $16.00
# Predicted Price: $92.22, Actual Price: $65.00
# Predicted Price: $94.45, Actual Price: $105.00
# Predicted Price: $140.04, Actual Price: $85.00
# Predicted Price: $107.08, Actual Price: $22.00
# Predicted Price: $114.55, Actual Price: $47.00
# Predicted Price: $478.93, Actual Price: $361.00
# Predicted Price: $103.36, Actual Price: $44.00
# Predicted Price: $116.57, Actual Price: $119.00
# Predicted Price: $93.91, Actual Price: $74.00
# Predicted Price: $124.80, Actual Price: $360.00
# Predicted Price: $110.87, Actual Price: $45.00
# Predicted Price: $161.52, Actual Price: $395.00
# Predicted Price: $191.84, Actual Price: $359.00
# Predicted Price: $101.73, Actual Price: $68.00
# Predicted Price: $93.04, Actual Price: $60.00
# Predicted Price: $102.01, Actual Price: $201.00
# Predicted Price: $91.66, Actual Price: $57.00
# Predicted Price: $109.58, Actual Price: $316.00
# Predicted Price: $124.40, Actual Price: $124.00
# Predicted Price: $120.61, Actual Price: $50.00
# Predicted Price: $116.03, Actual Price: $40.00
# Predicted Price: $105.00, Actual Price: $109.00
# Predicted Price: $101.27, Actual Price: $216.00
# Predicted Price: $168.58, Actual Price: $299.00
# Predicted Price: $92.92, Actual Price: $150.00
# Predicted Price: $95.95, Actual Price: $25.00
# Predicted Price: $116.60, Actual Price: $50.00
# Predicted Price: $92.04, Actual Price: $20.00
# Predicted Price: $209.55, Actual Price: $100.00
# Predicted Price: $115.78, Actual Price: $99.00
# Predicted Price: $93.38, Actual Price: $100.00
# Predicted Price: $98.61, Actual Price: $35.00
# Predicted Price: $94.14, Actual Price: $85.00
# Predicted Price: $124.01, Actual Price: $161.00
# Predicted Price: $129.61, Actual Price: $261.00
# Predicted Price: $98.87, Actual Price: $50.00
# Predicted Price: $125.65, Actual Price: $125.00
# Predicted Price: $121.96, Actual Price: $250.00
# Predicted Price: $117.65, Actual Price: $50.00
# Predicted Price: $106.88, Actual Price: $64.00
# Predicted Price: $93.47, Actual Price: $65.00
# Predicted Price: $118.36, Actual Price: $130.00
# Predicted Price: $111.92, Actual Price: $34.00
# Predicted Price: $96.27, Actual Price: $125.00
# Predicted Price: $110.23, Actual Price: $75.00
# Predicted Price: $92.04, Actual Price: $70.00
# Predicted Price: $95.48, Actual Price: $196.00
# Predicted Price: $92.00, Actual Price: $311.00
# Predicted Price: $126.24, Actual Price: $71.00
# Predicted Price: $92.80, Actual Price: $95.00
# Predicted Price: $102.17, Actual Price: $120.00
# Predicted Price: $109.50, Actual Price: $50.00
# Predicted Price: $111.81, Actual Price: $151.00
# Predicted Price: $92.27, Actual Price: $200.00
# Predicted Price: $103.53, Actual Price: $150.00
# Predicted Price: $110.21, Actual Price: $110.00
# Predicted Price: $93.46, Actual Price: $377.00
# Predicted Price: $92.23, Actual Price: $65.00
# Predicted Price: $107.94, Actual Price: $23.00
# Predicted Price: $100.92, Actual Price: $209.00
# Predicted Price: $92.75, Actual Price: $65.00
# Predicted Price: $101.05, Actual Price: $90.00
# Predicted Price: $93.08, Actual Price: $50.00
# Predicted Price: $123.26, Actual Price: $300.00
# Predicted Price: $107.67, Actual Price: $127.00
# Predicted Price: $108.43, Actual Price: $118.00
# Predicted Price: $172.82, Actual Price: $148.00
# Predicted Price: $97.59, Actual Price: $105.00
# Predicted Price: $101.31, Actual Price: $89.00
# Predicted Price: $92.51, Actual Price: $155.00
# Predicted Price: $112.86, Actual Price: $201.00
# Predicted Price: $106.23, Actual Price: $190.00
# Predicted Price: $124.79, Actual Price: $198.00
# Predicted Price: $104.13, Actual Price: $195.00
# Predicted Price: $203.68, Actual Price: $300.00
# Predicted Price: $99.71, Actual Price: $70.00
# Predicted Price: $103.68, Actual Price: $150.00
# Predicted Price: $116.70, Actual Price: $89.00
# Predicted Price: $109.10, Actual Price: $50.00
# Predicted Price: $100.38, Actual Price: $50.00
# Predicted Price: $106.11, Actual Price: $70.00
# Predicted Price: $105.45, Actual Price: $95.00
# Predicted Price: $340.90, Actual Price: $440.00
# Predicted Price: $192.50, Actual Price: $480.00
# Predicted Price: $112.44, Actual Price: $85.00
# Predicted Price: $134.70, Actual Price: $250.00
# Predicted Price: $98.61, Actual Price: $148.00
# Predicted Price: $153.40, Actual Price: $259.00
# Predicted Price: $123.40, Actual Price: $115.00
# Predicted Price: $112.86, Actual Price: $175.00
# Predicted Price: $106.09, Actual Price: $298.00
# Predicted Price: $92.58, Actual Price: $80.00
# Predicted Price: $110.63, Actual Price: $165.00
# Predicted Price: $95.56, Actual Price: $179.00
# Predicted Price: $112.62, Actual Price: $103.00
# Predicted Price: $133.14, Actual Price: $220.00
# Predicted Price: $130.92, Actual Price: $190.00
# Predicted Price: $104.51, Actual Price: $110.00
# Predicted Price: $92.33, Actual Price: $58.00
# Predicted Price: $100.84, Actual Price: $151.00
# Predicted Price: $136.05, Actual Price: $299.00
# Predicted Price: $102.60, Actual Price: $110.00
# Predicted Price: $103.02, Actual Price: $60.00
# Predicted Price: $100.15, Actual Price: $28.00
# Predicted Price: $101.18, Actual Price: $29.00
# Predicted Price: $114.72, Actual Price: $119.00
# Predicted Price: $93.96, Actual Price: $80.00
# Predicted Price: $102.21, Actual Price: $150.00
# Predicted Price: $106.00, Actual Price: $169.00
# Predicted Price: $102.07, Actual Price: $54.00
# Predicted Price: $92.24, Actual Price: $48.00
# Predicted Price: $106.66, Actual Price: $161.00
# Predicted Price: $115.92, Actual Price: $81.00
# Predicted Price: $203.16, Actual Price: $325.00
# Predicted Price: $92.63, Actual Price: $71.00
# Predicted Price: $93.38, Actual Price: $60.00
# Predicted Price: $92.17, Actual Price: $39.00
# Predicted Price: $92.22, Actual Price: $120.00
# Predicted Price: $129.90, Actual Price: $220.00
# Predicted Price: $145.88, Actual Price: $120.00
# Predicted Price: $117.20, Actual Price: $250.00
# Predicted Price: $92.28, Actual Price: $100.00
# Predicted Price: $94.64, Actual Price: $399.00
# Predicted Price: $108.18, Actual Price: $130.00
# Predicted Price: $94.55, Actual Price: $111.00
# Predicted Price: $117.20, Actual Price: $99.00
# Predicted Price: $125.90, Actual Price: $119.00
# Predicted Price: $99.83, Actual Price: $269.00
# Predicted Price: $143.79, Actual Price: $80.00
# Predicted Price: $104.49, Actual Price: $142.00
# Predicted Price: $121.54, Actual Price: $100.00
# Predicted Price: $97.64, Actual Price: $29.00
# Predicted Price: $92.43, Actual Price: $30.00
# Predicted Price: $99.92, Actual Price: $38.00
# Predicted Price: $92.84, Actual Price: $40.00
# Predicted Price: $99.65, Actual Price: $25.00
# Predicted Price: $92.05, Actual Price: $22.00
# Predicted Price: $97.91, Actual Price: $229.00
# Predicted Price: $102.16, Actual Price: $45.00
# Predicted Price: $91.82, Actual Price: $70.00
# Predicted Price: $91.90, Actual Price: $90.00
# Predicted Price: $105.78, Actual Price: $150.00
# Predicted Price: $110.87, Actual Price: $171.00
# Predicted Price: $129.66, Actual Price: $62.00
# Predicted Price: $172.21, Actual Price: $199.00
# Predicted Price: $100.61, Actual Price: $30.00
# Predicted Price: $114.13, Actual Price: $50.00
# Predicted Price: $112.01, Actual Price: $105.00
# Predicted Price: $125.21, Actual Price: $110.00
# Predicted Price: $111.87, Actual Price: $50.00
# Predicted Price: $121.62, Actual Price: $129.00
# Predicted Price: $93.75, Actual Price: $50.00
# Predicted Price: $143.49, Actual Price: $119.00
# Predicted Price: $93.09, Actual Price: $100.00
# Predicted Price: $92.95, Actual Price: $55.00
# Predicted Price: $184.51, Actual Price: $399.00
# Predicted Price: $102.99, Actual Price: $125.00
# Predicted Price: $147.87, Actual Price: $185.00
# Predicted Price: $121.75, Actual Price: $420.00
# Predicted Price: $136.42, Actual Price: $199.00
# Predicted Price: $126.38, Actual Price: $60.00
# Predicted Price: $93.18, Actual Price: $52.00
# Predicted Price: $118.66, Actual Price: $171.00
# Predicted Price: $92.28, Actual Price: $95.00
# Predicted Price: $163.94, Actual Price: $125.00
# Predicted Price: $127.59, Actual Price: $110.00
# Predicted Price: $217.87, Actual Price: $169.00
# Predicted Price: $158.64, Actual Price: $255.00
# Predicted Price: $123.97, Actual Price: $298.00
# Predicted Price: $97.55, Actual Price: $20.00
# Predicted Price: $226.66, Actual Price: $413.00
# Predicted Price: $92.66, Actual Price: $100.00
# Predicted Price: $102.76, Actual Price: $149.00
# Predicted Price: $116.89, Actual Price: $166.00
# Predicted Price: $93.92, Actual Price: $158.00
# Predicted Price: $110.53, Actual Price: $261.00
# Predicted Price: $98.34, Actual Price: $55.00
# Predicted Price: $126.70, Actual Price: $228.00
# Predicted Price: $106.10, Actual Price: $85.00
# Predicted Price: $92.60, Actual Price: $35.00
# Predicted Price: $182.45, Actual Price: $245.00
# Predicted Price: $94.72, Actual Price: $108.00
# Predicted Price: $186.38, Actual Price: $179.00
# Predicted Price: $92.15, Actual Price: $250.00
# Predicted Price: $99.56, Actual Price: $18.00
# Predicted Price: $120.31, Actual Price: $75.00
# Predicted Price: $103.90, Actual Price: $75.00
# Predicted Price: $108.40, Actual Price: $179.00
# Predicted Price: $112.36, Actual Price: $139.00
# Predicted Price: $92.83, Actual Price: $84.00
# Predicted Price: $130.51, Actual Price: $120.00
# Predicted Price: $184.83, Actual Price: $185.00
# Predicted Price: $169.30, Actual Price: $220.00
# Predicted Price: $123.79, Actual Price: $50.00
# Predicted Price: $91.75, Actual Price: $65.00
# Predicted Price: $112.64, Actual Price: $138.00
# Predicted Price: $93.35, Actual Price: $50.00
# Predicted Price: $100.27, Actual Price: $68.00
# Predicted Price: $96.34, Actual Price: $30.00
# Predicted Price: $103.07, Actual Price: $30.00
# Predicted Price: $106.55, Actual Price: $300.00
# Predicted Price: $202.68, Actual Price: $119.00
# Predicted Price: $133.44, Actual Price: $299.00
# Predicted Price: $95.13, Actual Price: $85.00
# Predicted Price: $121.52, Actual Price: $100.00
# Predicted Price: $92.04, Actual Price: $99.00
# Predicted Price: $96.59, Actual Price: $139.00
# Predicted Price: $104.18, Actual Price: $27.00
# Predicted Price: $111.56, Actual Price: $99.00
# Predicted Price: $123.24, Actual Price: $42.00
# Predicted Price: $117.71, Actual Price: $190.00
# Predicted Price: $126.48, Actual Price: $400.00
# Predicted Price: $103.41, Actual Price: $220.00
# Predicted Price: $104.07, Actual Price: $45.00
# Predicted Price: $114.56, Actual Price: $416.00
# Predicted Price: $91.48, Actual Price: $181.00
# Predicted Price: $107.99, Actual Price: $228.00
# Predicted Price: $92.78, Actual Price: $69.00
# Predicted Price: $101.36, Actual Price: $34.00
# Predicted Price: $95.82, Actual Price: $60.00
# Predicted Price: $96.25, Actual Price: $15.00
# Predicted Price: $99.05, Actual Price: $30.00
# Predicted Price: $92.65, Actual Price: $80.00
# Predicted Price: $111.78, Actual Price: $50.00
# Predicted Price: $93.32, Actual Price: $90.00
# Predicted Price: $110.61, Actual Price: $199.00
# Predicted Price: $125.01, Actual Price: $188.00
# Predicted Price: $346.79, Actual Price: $428.00
# Predicted Price: $92.91, Actual Price: $75.00
# Predicted Price: $174.29, Actual Price: $120.00
# Predicted Price: $125.32, Actual Price: $70.00
# Predicted Price: $92.34, Actual Price: $124.00
# Predicted Price: $147.97, Actual Price: $249.00
# Predicted Price: $137.72, Actual Price: $118.00
# Predicted Price: $144.30, Actual Price: $95.00
# Predicted Price: $91.91, Actual Price: $75.00
# Predicted Price: $92.31, Actual Price: $353.00
# Predicted Price: $105.16, Actual Price: $479.00
# Predicted Price: $118.52, Actual Price: $101.00
# Predicted Price: $105.80, Actual Price: $108.00
# Predicted Price: $92.86, Actual Price: $53.00
# Predicted Price: $94.10, Actual Price: $60.00
# Predicted Price: $147.04, Actual Price: $79.00
# Predicted Price: $113.19, Actual Price: $163.00
# Predicted Price: $97.27, Actual Price: $283.00
# Predicted Price: $93.91, Actual Price: $69.00
# Predicted Price: $95.47, Actual Price: $150.00
# Predicted Price: $120.64, Actual Price: $295.00
# Predicted Price: $150.18, Actual Price: $305.00
# Predicted Price: $104.87, Actual Price: $60.00
# Predicted Price: $101.63, Actual Price: $55.00
# Predicted Price: $106.73, Actual Price: $56.00
# Predicted Price: $178.87, Actual Price: $129.00
# Predicted Price: $94.41, Actual Price: $141.00
# Predicted Price: $206.45, Actual Price: $301.00
# Predicted Price: $94.31, Actual Price: $179.00
# Predicted Price: $130.68, Actual Price: $130.00
# Predicted Price: $104.17, Actual Price: $361.00
# Predicted Price: $133.71, Actual Price: $200.00
# Predicted Price: $161.98, Actual Price: $57.00
# Predicted Price: $265.71, Actual Price: $450.00
# Predicted Price: $103.78, Actual Price: $119.00
# Predicted Price: $92.75, Actual Price: $70.00
# Predicted Price: $92.82, Actual Price: $88.00
# Predicted Price: $91.97, Actual Price: $65.00
# Predicted Price: $137.91, Actual Price: $33.00
# Predicted Price: $119.79, Actual Price: $100.00
# Predicted Price: $110.15, Actual Price: $50.00
# Predicted Price: $105.00, Actual Price: $38.00
# Predicted Price: $154.58, Actual Price: $64.00
# Predicted Price: $113.84, Actual Price: $13.00
# Predicted Price: $113.85, Actual Price: $40.00
# Predicted Price: $94.90, Actual Price: $79.00
# Predicted Price: $149.60, Actual Price: $99.00
# Predicted Price: $122.77, Actual Price: $59.00
# Predicted Price: $94.03, Actual Price: $330.00
# Predicted Price: $93.28, Actual Price: $84.00
# Predicted Price: $109.61, Actual Price: $100.00
# Predicted Price: $111.59, Actual Price: $60.00
# Predicted Price: $205.17, Actual Price: $189.00
# Predicted Price: $111.76, Actual Price: $108.00

# %%
# Show metrics of model performance
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Calculate the mean squared error
mse = mean_squared_error(actual_prices, predictions_unscaled)
print(f"Mean Squared Error: {mse:.2f}")

# Calculate the mean absolute error
mae = mean_absolute_error(actual_prices, predictions_unscaled)
print(f"Mean Absolute Error: {mae:.2f}")

# Calculate the R^2 score
r2 = r2_score(actual_prices, predictions_unscaled)
print(f"R^2 Score: {r2:.2f}")

# Plot the predicted vs. actual prices
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.scatter(actual_prices, predictions_unscaled, color='blue')
plt.xlabel('Actual Price')
plt.ylabel('Predicted Price')
plt.title('Predicted vs. Actual Price')
plt.show()
# Out:
# Mean Squared Error: 10150.05
# Mean Absolute Error: 70.45
# R^2 Score: 0.12

# %% [markdown]
# # THIS THING FOR ONE RUN DATA PREPROCESSING

# %%
import pandas as pd
import json
import os

def load_json_subset(path):
    # Load the entire file into a JSON object
    with open(path, 'r') as file:
        data = json.load(file)  # Assuming the entire file is one large JSON array of objects

    # Convert the data to a DataFrame
    df = pd.DataFrame(data)
    return df

# Load the DataFrame
df = load_json_subset('/Users/grantrobinett/2024/COE379L-Robinett/project4/airbnbData.json')
print(f"Original DataFrame size: {df.shape}")

# Load unsuccessful IDs from log file
with open('unsuccessful_downloads.log', 'r') as file:
    unsuccessful_ids = file.read().splitlines()

# Convert unsuccessful_ids to the correct data type if necessary
unsuccessful_ids = [int(id) for id in unsuccessful_ids]  # Convert to int if IDs are integers

# Filter the DataFrame
filter_df = df[~df['_id'].isin(unsuccessful_ids)]
print(f"Filtered DataFrame size: {filter_df.shape}")

# Remove folders and files for unsuccessful IDs
for id in unsuccessful_ids:
    directory_path = os.path.join('imagesData', str(id))  # Ensure the path uses str(id) if needed
    if os.path.exists(directory_path) and os.path.isdir(directory_path):
        for file in os.listdir(directory_path):
            os.remove(os.path.join(directory_path, file))
        os.rmdir(directory_path)

# Count remaining folders
remaining_folders = len(os.listdir('imagesData'))
print(f"Number of remaining folders in 'imagesData': {remaining_folders}")

#
# SECTION 2: DATA PREPROCESSING
#

import pandas as pd
import numpy as np

# Define a function to safely extract review_scores_rating
def get_review_scores_rating(review_scores):
    if pd.isna(review_scores):
        return np.nan
    return review_scores.get('review_scores_rating', np.nan)

# Define a function to safely extract review_scores_value
def get_review_scores_value(review_scores):
    if pd.isna(review_scores):
        return np.nan
    return review_scores.get('review_scores_value', np.nan)

# Apply this function to the 'review_scores' column
filter_df['review_scores_rating'] = filter_df['review_scores'].apply(get_review_scores_rating)
filter_df['review_scores_value'] = filter_df['review_scores'].apply(get_review_scores_value)



# Add 'review_scores_rating' to the columns list
columns_used = ['_id', 'name', 'summary', 'description', 'neighborhood_overview', 'notes', 
                'property_type', 'room_type', 'accommodates', 'bedrooms', 'beds', 
                'bathrooms', 'bed_type', 'amenities', 'price', 'review_scores_rating', 'review_scores_value', 'number_of_reviews']
filter_df = filter_df[columns_used]

# Check all columns for NaN values
nan_values = filter_df.isna().sum()
print(nan_values)

# Drop rows with NaN values
filter_df = filter_df.dropna()

# Check all columns for NaN values
nan_values = filter_df.isna().sum()
print(nan_values)

# describe price
price_description = filter_df['price'].describe()
print(price_description)

# Remove prices above 1000
filter_df = filter_df[filter_df['price'] <= 500]

# describe price again
price_description = filter_df['price'].describe()
print(price_description)

# Shape of the DataFrame
print(filter_df.shape)

#
# SECTION 3: ENCODING AND SCALING
#

# Now, let's One-Hot Encode the categorical columns 'property_type', 'room_type', and 'bed_type'.
# One-Hot Encoding
filter_df = pd.get_dummies(filter_df, columns=['property_type', 'room_type', 'bed_type'])

from sklearn.preprocessing import MinMaxScaler
from joblib import dump, load

# Initialize the MinMaxScaler
scaler = MinMaxScaler()

# Define all numerical columns that need scaling
numerical_columns = ['accommodates', 'bedrooms', 'beds', 'bathrooms', 'review_scores_rating','review_scores_value' ,'price']

# Fit the scaler to these columns
scaler.fit(filter_df[numerical_columns])

# Transform the data using the fitted scaler
filter_df[numerical_columns] = scaler.transform(filter_df[numerical_columns])

# Save the scaler for later use
dump(scaler, 'scaler_numerical.joblib')

# Check the scaled DataFrame
print(filter_df[numerical_columns].describe())

#
# SECTION 4: SPLITTING DATA
#

import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
import numpy as np

columns_X_included = ['accommodates', 'bedrooms', 'beds', 'bathrooms', 'review_scores_rating', 'review_scores_value', 'property_type_Aparthotel', 'property_type_Apartment', 'property_type_Barn', 'property_type_Bed and breakfast', 'property_type_Boat', 'property_type_Boutique hotel', 'property_type_Bungalow', 'property_type_Cabin', 'property_type_Camper/RV', 'property_type_Campsite', 'property_type_Casa particular (Cuba)', 'property_type_Chalet', 'property_type_Condominium', 'property_type_Cottage', 'property_type_Earth house', 'property_type_Farm stay', 'property_type_Guest suite', 'property_type_Guesthouse', 'property_type_Hostel', 'property_type_Hotel', 'property_type_House', 'property_type_Hut', 'property_type_Loft', 'property_type_Other', 'property_type_Resort', 'property_type_Serviced apartment', 'property_type_Tiny house', 'property_type_Townhouse', 'property_type_Train', 'property_type_Treehouse', 'property_type_Villa', 'room_type_Entire home/apt', 'room_type_Private room', 'room_type_Shared room', 'bed_type_Airbed', 'bed_type_Couch', 'bed_type_Futon', 'bed_type_Pull-out Sofa', 'bed_type_Real Bed']

# Initialize a TF-IDF Vectorizer
tfidf_vectorizer = TfidfVectorizer(max_features=100, stop_words='english')

# Fit and transform the 'description' column (assuming 'description' is similar to 'summary')
X_tfidf = tfidf_vectorizer.fit_transform(filter_df['description']).toarray()

# Assuming X is your original feature matrix
X_numerical = filter_df[columns_X_included]  # Ensure 'columns_X_included' doesn't include 'price'

# Concatenate the TF-IDF features to your numerical feature set
X_final = np.hstack([X_numerical, X_tfidf])

# Define the target variable
y = filter_df['price']

# Create bins for the 'price' data into quartiles
price_bins = pd.qcut(y, q=4, labels=False, duplicates='drop')

# Split the data into training and testing sets with stratification
X_train, X_test, y_train, y_test = train_test_split(
    X_final,  # Combined feature set
    y,        # Prices
    test_size=0.2,
    random_state=42,
    stratify=price_bins  # Use the price bins for stratification
)

# Now your split should have similar distributions of price across train and test sets
# Out:
# Original DataFrame size: (5555, 43)
# Filtered DataFrame size: (4610, 43)
# Number of remaining folders in 'imagesData': 4611
# _id                         0
# name                        0
# summary                     0
# description                 0
# neighborhood_overview       0
# notes                       0
# property_type               0
# room_type                   0
# accommodates                0
# bedrooms                    5
# beds                       13
# bathrooms                  10
# bed_type                    0
# amenities                   0
# price                       0
# review_scores_rating     1266
# review_scores_value      1266
# number_of_reviews           0
# dtype: int64
# _id                      0
# name                     0
# summary                  0
# description              0
# neighborhood_overview    0
# notes                    0
# property_type            0
# room_type                0
# accommodates             0
# bedrooms                 0
# beds                     0
# bathrooms                0
# bed_type                 0
# amenities                0
# price                    0
# review_scores_rating     0
# review_scores_value      0
# number_of_reviews        0
# dtype: int64
# count     3334.000000
# mean       229.350330
# std        423.936265
# min         10.000000
# 25%         68.000000
# 50%        120.000000
# 75%        250.000000
# max      11681.000000
# Name: price, dtype: float64
# count    2992.000000
# mean      141.397059
# std       108.028740
# min        10.000000
# 25%        61.750000
# 50%       101.500000
# 75%       190.000000
# max       500.000000
# Name: price, dtype: float64
# (2992, 18)
#        accommodates     bedrooms         beds    bathrooms  \
# count   2992.000000  2992.000000  2992.000000  2992.000000
# mean       0.158445     0.067346     0.078810     0.077164
# std        0.140657     0.049706     0.060756     0.037813
# min        0.000000     0.000000     0.000000     0.000000
# 25%        0.066667     0.050000     0.040000     0.062500
# 50%        0.133333     0.050000     0.040000     0.062500
# 75%        0.200000     0.100000     0.080000     0.062500
# max        1.000000     1.000000     1.000000     1.000000
#
#        review_scores_rating  review_scores_value        price
# count           2992.000000          2992.000000  2992.000000
# mean               0.912379             0.914062     0.268157
# std                0.114809             0.118076     0.220467
# min                0.000000             0.000000     0.000000
# 25%                0.875000             0.875000     0.105612
# 50%                0.937500             0.875000     0.186735
# 75%                0.987500             1.000000     0.367347
# max                1.000000             1.000000     1.000000
# /var/folders/r1/x17z5wq913s3rgkc6t0y_m0h0000gn/T/ipykernel_5105/3155375667.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filter_df['review_scores_rating'] = filter_df['review_scores'].apply(get_review_scores_rating)
# /var/folders/r1/x17z5wq913s3rgkc6t0y_m0h0000gn/T/ipykernel_5105/3155375667.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filter_df['review_scores_value'] = filter_df['review_scores'].apply(get_review_scores_value)

# %%
from tensorflow.keras.preprocessing.image import load_img, img_to_array
import numpy as np
import os

def load_and_preprocess_image(image_path, target_size=(224, 224)):
    img = load_img(image_path, target_size=target_size)
    img_array = img_to_array(img)
    img_array /= 255.0  # Normalize to [0, 1]
    return img_array

# Assuming each ID has exactly one image in its folder for simplicity
def load_images(data_frame, base_path='/Users/grantrobinett/2024/COE379L-Robinett/project4/imagesData'):
    images = []
    for idx in data_frame['_id']:
        folder_path = os.path.join(base_path, str(idx))
        image_files = os.listdir(folder_path)
        if image_files:
            # Load the first image in the folder
            image_path = os.path.join(folder_path, image_files[0])
            img_array = load_and_preprocess_image(image_path)
            images.append(img_array)
        else:
            # Append a zero array if no image is found
            images.append(np.zeros((224, 224, 3)))
    return np.array(images)

# Load images corresponding to the IDs in filter_df
images = load_images(filter_df)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

def create_image_model():
    model = Sequential([
        Conv2D(32, (3, 3), activation='relu', input_shape=(224, 224, 3)),
        MaxPooling2D(2, 2),
        Conv2D(64, (3, 3), activation='relu'),
        MaxPooling2D(2, 2),
        Conv2D(128, (3, 3), activation='relu'),
        MaxPooling2D(2, 2),
        Flatten(),
        Dense(128, activation='relu'),
        Dense(64, activation='relu')
    ])
    return model

image_model = create_image_model()

# %%
from tensorflow.keras.layers import concatenate, Input
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout

# Input layers
structured_input = Input(shape=(X_train.shape[1],))
image_input = Input(shape=(224, 224, 3))

# Get image features using the predefined image model
image_features = image_model(image_input)

# Combine image features with structured data
combined_features = concatenate([structured_input, image_features])

# Final part of the network for prediction
x = Dense(256, activation='relu')(combined_features)
x = Dropout(0.2)(x)
output = Dense(1)(x)  # Assuming regression; change to softmax if classification

# Full model combining structured and image inputs
full_model = Model(inputs=[structured_input, image_input], outputs=output)

# Compile the model
full_model.compile(optimizer='adam', loss='mean_squared_error')

# Now prepare structured data and images for training
from sklearn.model_selection import train_test_split

# Assuming `X_final` is your structured data prepared earlier and `images` is loaded as previously described
X_train_structured, X_test_structured, images_train, images_test, y_train, y_test = train_test_split(
    X_final, images, y, test_size=0.2, random_state=42
)

# Train the model
history = full_model.fit(
    [X_train_structured, images_train], y_train,
    validation_data=([X_test_structured, images_test], y_test),
    epochs=10,  # Adjust epochs based on early stopping and validation loss trends
    batch_size=32,
    verbose=1
)

# Evaluate the model
loss = full_model.evaluate([X_test_structured, images_test], y_test, verbose=2)
print(f"Mean Squared Error: {loss}")
# Out:
# Epoch 1/10
# 75/75 [==============================] - 103s 1s/step - loss: 0.0457 - val_loss: 0.0346
# Epoch 2/10
# 54/75 [====================>.........] - ETA: 26s - loss: 0.0354

# %%
# Now, save the model using tf serving
# Save the model
full_model.save('models/NN_FINAL_WITH_IMAGES', save_format='tf')
